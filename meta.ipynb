# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy  as np
import seaborn as sns
import os
direc = '/home/tejaswik/Documents/CurrentProjects/chills/categoriesChills/'
maindir = os.listdir(direc)

# %%
df = pd.DataFrame.from_csv('/home/tejaswik/Dropbox/annot.csv')

# %%
df
# Out:
#     Vocal              Genre
# 1       F               Jazz
# 2       M               Rock
# 3       M  Singer-Songwriter
# 4       M               Rock
# 5       M              Metal
# 6    Inst             Trance
# 7       F  Singer-Songwriter
# 8       M               Funk
# 9    Inst          Classical
# 10      M                Pop
# 11      M                Pop
# 12      M                Pop
# 13      M              Metal
# 14      F              Blues
# 15      M               Punk
# 16      M              Metal
# 17   Inst          Classical
# 18      M              Metal
# 19      M                Pop
# 20      M                Pop
# 21      M              Metal
# 22      M                Pop
# 23   Inst                OST
# 24      M              Metal
# 25      F               Folk
# 26      M              Metal
# 27      F    Musical Theater
# 28      M              Metal
# 29      F                Pop
# 30      M                Pop
# ..    ...                ...
# ...

# %%
from collections import Counter

# %%
genres = dict(Counter(df['Genre']))
genres = pd.DataFrame.from_dict(genres, orient='index')
genres.sort_values(by = 0,ascending=False)
# Out:
#                     0
# Metal              35
# Pop                30
# Rock               26
# Singer-Songwriter  15
# Classical          11
# Musical Theater     7
# Folk                6
# OST                 5
# Trance              5
# Jazz                4
# Blues               3
# Funk                2
# Rhythm And Blues    1
# Punk                1
# Soul                1
# EDM                 1
# Techno              1
# Rap                 1
# Country             1

# %% [markdown]
# # Genres

# %%
genres.plot(kind = 'bar',subplots=True,figsize = (16,10),fontsize=28)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7710d8a650>],
#       dtype=object)

# %% [markdown]
# # Singers' genders

# %%
insts = dict(Counter(df['Vocal']))
insts = pd.DataFrame.from_dict(insts,orient = 'index')
insts.plot(kind ='bar',subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7711479250>],
#       dtype=object)
